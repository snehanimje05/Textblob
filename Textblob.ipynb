# %%
# !pip insatll -U textblob
! python -m textblob.download_corpora
# Out:
# ERROR: unknown command "insatll" - maybe you meant "install"
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
from textblob import TextBlob

# %%
text='Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!'
blob=TextBlob(text)

# %%
blob.correct()
# Out:
# TextBlob("Are you ready to embark on an exciting journey into the word of Data Science He have an incredible opportunity for you to showcase your skill and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.44375, subjectivity=0.875)

# %%
blob.classify
# Out:
# <bound method BaseBlob.classify of TextBlob("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")>

# %%
blob.format
# Out:
# <bound method StringlikeMixin.format of TextBlob("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")>

# %%
blob.word_counts['Are']
# Out:
# 0

# %%
blob.word_counts['are']
# Out:
# 1

# %%
blob.endswith
# Out:
# <bound method StringlikeMixin.endswith of TextBlob("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")>

# %%
blob.tags
# Out:
# [('Are', 'NNP'),
#  ('you', 'PRP'),
#  ('rady', 'VBP'),
#  ('to', 'TO'),
#  ('embark', 'VB'),
#  ('on', 'IN'),
#  ('an', 'DT'),
#  ('exciting', 'JJ'),
#  ('journey', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('word', 'NN'),
#  ('of', 'IN'),
#  ('Data', 'NNP'),
#  ('Science', 'NNP'),
#  ('We', 'PRP'),
#  ('have', 'VBP'),
#  ('an', 'DT'),
#  ('incredible', 'JJ'),
#  ('opprtunity', 'NN'),
#  ('for', 'IN'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('showcase', 'VB'),
#  ('your', 'PRP$'),
#  ('skills', 'NNS'),
#  ('and', 'CC'),
#  ('passion', 'NN'),
#  ('Our', 'PRP$'),
#  ('Data', 'NNS'),
#  ('Science', 'NNP'),
#  ('Internship', 'NNP'),
#  ('Program', 'NNP'),
#  ('is', 'VBZ'),
#  ('just', 'RB'),
#  ('a', 'DT'),
#  ('test', 'NN'),
#  ('away', 'RB'),
#  ('and', 'CC'),
#  ('were', 'VBD'),
#  ('looking', 'VBG'),
#  ('for', 'IN'),
#  ('bright', 'NN'),
#  ('curious', 'JJ'),
#  ('minds', 'NNS'),
#  ('like', 'IN'),
#  ('yours', 'NN')]

# %%
blob.detect_language
# Out:
# <bound method BaseBlob.detect_language of TextBlob("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")>

# %%
blob.index
# Out:
# <bound method StringlikeMixin.index of TextBlob("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")>

# %%
blob.join
# Out:
# <bound method StringlikeMixin.join of TextBlob("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")>

# %%
blob.find
# Out:
# <bound method StringlikeMixin.find of TextBlob("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion. Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")>

# %%
new_tuple=[]
for i in blob.tags:
  if 'VBP' not in i[1]:
    new_tuple.append(i)

# %%
new_tuple
# Out:
# [('Are', 'NNP'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('embark', 'VB'),
#  ('on', 'IN'),
#  ('an', 'DT'),
#  ('exciting', 'JJ'),
#  ('journey', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('word', 'NN'),
#  ('of', 'IN'),
#  ('Data', 'NNP'),
#  ('Science', 'NNP'),
#  ('We', 'PRP'),
#  ('an', 'DT'),
#  ('incredible', 'JJ'),
#  ('opprtunity', 'NN'),
#  ('for', 'IN'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('showcase', 'VB'),
#  ('your', 'PRP$'),
#  ('skills', 'NNS'),
#  ('and', 'CC'),
#  ('passion', 'NN'),
#  ('Our', 'PRP$'),
#  ('Data', 'NNS'),
#  ('Science', 'NNP'),
#  ('Internship', 'NNP'),
#  ('Program', 'NNP'),
#  ('is', 'VBZ'),
#  ('just', 'RB'),
#  ('a', 'DT'),
#  ('test', 'NN'),
#  ('away', 'RB'),
#  ('and', 'CC'),
#  ('were', 'VBD'),
#  ('looking', 'VBG'),
#  ('for', 'IN'),
#  ('bright', 'NN'),
#  ('curious', 'JJ'),
#  ('minds', 'NNS'),
#  ('like', 'IN'),
#  ('yours', 'NN')]

# %%
value=''
for i in new_tuple:
  value=value+' '+''.join(i[0])

# %%
value
# Out:
# ' Are you to embark on an exciting journey into the word of Data Science We an incredible opprtunity for you to showcase your skills and passion Our Data Science Internship Program is just a test away and were looking for bright curious minds like yours'

# %%
corpus_word=blob.words

# %%
corpus_word
# Out:
# WordList(['Are', 'you', 'rady', 'to', 'embark', 'on', 'an', 'exciting', 'journey', 'into', 'the', 'word', 'of', 'Data', 'Science', 'We', 'have', 'an', 'incredible', 'opprtunity', 'for', 'you', 'to', 'showcase', 'your', 'skills', 'and', 'passion', 'Our', 'Data', 'Science', 'Internship', 'Program', 'is', 'just', 'a', 'test', 'away', 'and', 'were', 'looking', 'for', 'bright', 'curious', 'minds', 'like', 'yours'])

# %%
print(len(corpus_word))
# Out:
# 47

# %%
corpus_sentence=blob.sentences

# %%
corpus_sentence
# Out:
# [Sentence("Are you rady to embark on an exciting journey into the word of Data Science We have an incredible opprtunity for you to showcase your skills and passion."),
#  Sentence("Our Data Science Internship Program is just a test away, and were looking for bright, curious minds like yours!")]

# %%
print(len(corpus_sentence))
# Out:
# 2

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import spacy
from nltk.tokenize.toktok import ToktokTokenizer
import re
tokenizer=ToktokTokenizer()
nlp=spacy.load('en_core_web_sm',disable=['ner'])

# %%
TextBlob('he is very good boy').sentiment
# Out:
# Sentiment(polarity=0.9099999999999999, subjectivity=0.7800000000000001)

# %%
TextBlob('Everybody says tis man is poor').sentiment
# Out:
# Sentiment(polarity=-0.4, subjectivity=0.6)
